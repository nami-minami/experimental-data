# %%
import numpy as np 
import matplotlib.pyplot as plt 

pH = np.arange(0,14.1, 0.1)
H = 10**-pH
K_1 = 9e-6
K_2 = 2e-10
nu = K_1*K_2/H**2 + K_1/H + 1 

a_0 = nu**-1 
a_1 = K_1/H/nu
a_2 = K_1*K_2/H**2/nu

plt.plot(pH, a_0)
plt.plot(pH, a_1)
plt.plot(pH, a_2)
