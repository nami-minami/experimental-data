# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import japanize_matplotlib

df01 = pd.read_csv("0-3.csv") 
df02 = pd.read_csv("0-4.csv")
df201 = pd.read_csv("20-2.csv")
df202 = pd.read_csv("20-3.csv")
df301 = pd.read_csv("30-1.csv")
df302 = pd.read_csv("30-2.csv")
df601 = pd.read_csv("60-2.csv")
df602 = pd.read_csv("60-3.csv")
df801 = pd.read_csv("80-1.csv")
df802 = pd.read_csv("80-2.csv")
df1001 = pd.read_csv("100-1.csv")
df1002 = pd.read_csv("100-2.csv")

fig, ax = plt.subplots(6,2, figsize=(25,25))

for i in range(2):
    for j in range(6):
        ax[j,i].set_xlabel("時間")
        ax[j,i].set_ylabel("温度")
        ax[j,i].tick_params(direction="in")

ax[0,0].scatter(df01['time'], df01["temp"], s=5, color="black")
ax[0,1].scatter(df02['time'], df02["temp"], s=5, color="black")
ax[1,0].scatter(df201['time'], df201["temp"], s=5, color="black")
ax[1,1].scatter(df202['time'], df202["temp"], s=5, color="black")
ax[2,0].scatter(df301['time'], df301["temp"], s=5, color="black")
ax[2,1].scatter(df302['time'], df302["temp"], s=5, color="black")
ax[3,0].scatter(df601['time'], df601["temp"], s=5, color="black")
ax[3,1].scatter(df602['time'], df602["temp"], s=5, color="black")
ax[4,0].scatter(df801['time'], df801["temp"], s=5, color="black")
ax[4,1].scatter(df802['time'], df802["temp"], s=5, color="black")
ax[5,0].scatter(df1001['time'], df1001["temp"], s=5, color="black")
ax[5,1].scatter(df1002['time'], df1002["temp"], s=5, color="black")

plt.savefig("pd.pdf")
